# %%
import pandas as pd
import numpy as np
from pathlib import Path
# %matplotlib inline

# %%
# Read the 2023 Team stats into pandas dataframes

niners = pd.read_excel('Data/49ers_2023.xlsx')
bears = pd.read_excel('Data/Bears_2023.xlsx')
bengals = pd.read_excel('Data/Bengals_2023.xlsx')
bills = pd.read_excel('Data/Bills_2023.xlsx')
broncos = pd.read_excel('Data/Broncos_2023.xlsx')
browns = pd.read_excel('Data/Browns_2023.xlsx')
buccaneers = pd.read_excel('Data/Buccaneers_2023.xlsx')
cardinals = pd.read_excel('Data/Cardinals_2023.xlsx')
chargers = pd.read_excel('Data/Chargers_2023.xlsx')
chiefs = pd.read_excel('Data/Chiefs_2023.xlsx')
colts = pd.read_excel('Data/Colts_2023.xlsx')
commanders = pd.read_excel('Data/Commanders_2023.xlsx')
cowboys = pd.read_excel('Data/Cowboys_2023.xlsx')
dolphins = pd.read_excel('Data/Dolphins_2023.xlsx')
eagles = pd.read_excel('Data/Eagles_2023.xlsx')
falcons = pd.read_excel('Data/Falcons_2023.xlsx')
giants = pd.read_excel('Data/Giants_2023.xlsx')
jaguars = pd.read_excel('Data/Jaguars_2023.xlsx')
jets = pd.read_excel('Data/Jets_2023.xlsx')
lions = pd.read_excel('Data/Lions_2023.xlsx')
packers = pd.read_excel('Data/Packers_2023.xlsx')
panthers = pd.read_excel('Data/Panthers_2023.xlsx')
patriots = pd.read_excel('Data/Patriots_2023.xlsx')
raiders = pd.read_excel('Data/Raiders_2023.xlsx')
rams = pd.read_excel('Data/Rams_2023.xlsx')
ravens = pd.read_excel('Data/Ravens_2023.xlsx')
saints = pd.read_excel('Data/Saints_2023.xlsx')
seahawks = pd.read_excel('Data/Seahawks_2023.xlsx')
steelers = pd.read_excel('Data/Steelers_2023.xlsx')
texans = pd.read_excel('Data/Texans_2023.xlsx')
titans = pd.read_excel('Data/Titans_2023.xlsx')
vikings =  pd.read_excel('Data/Vikings_2023.xlsx')

# %%
broncos.head()
# Out:
#    Week       Date Result  OT Record Home               Opponent  \
# 0     1 2024-09-10      L NaN    0-1  NaN      Las Vegas Raiders
# 1     2 2024-09-17      L NaN    0-2  NaN  Washington Commanders
# 2     3 2024-09-24      L NaN    0-3    @         Miami Dolphins
# 3     4 2024-10-01      W NaN    1-3    @          Chicago Bears
# 4     5 2024-10-08      L NaN    1-4  NaN          New York Jets
#
#    Points Scored  Points Allowed  1st Downs  ...   Rushing Yards  \
# 0             16              17         22  ...              94
# 1             33              35         21  ...             122
# 2             20              70         16  ...              69
# 3             31              28         17  ...              97
# 4             21              31         18  ...             139
#
#    Turnovers Lost  1st Downs Allowed  Total Yards Allowed  \
# 0             NaN                 22                  261
# 1             2.0                 26                  388
# ...

# %%
niners = niners[0:17].drop(columns=['Date', 'OT'])
bears = bears[0:17].drop(columns=['Date', 'OT'])
bengals = bengals[0:17].drop(columns=['Date', 'OT'])
bills = bills[0:17].drop(columns=['Date', 'OT'])
broncos = broncos[0:17].drop(columns=['Date', 'OT'])
browns = browns[0:17].drop(columns=['Date', 'OT'])
buccaneers = buccaneers[0:17].drop(columns=['Date', 'OT'])
cardinals = cardinals[0:17].drop(columns=['Date', 'OT'])
chargers = chargers[0:17].drop(columns=['Date', 'OT'])
chiefs = chiefs[0:17].drop(columns=['Date', 'OT'])
colts = colts[0:17].drop(columns=['Date', 'OT'])
commanders = commanders[0:17].drop(columns=['Date', 'OT'])
cowboys = cowboys[0:17].drop(columns=['Date', 'OT'])
dolphins = dolphins[0:17].drop(columns=['Date', 'OT'])
eagles = eagles[0:17].drop(columns=['Date', 'OT'])
falcons = falcons[0:17].drop(columns=['Date', 'OT'])
giants = giants[0:17].drop(columns=['Date', 'OT'])
jaguars = jaguars[0:17].drop(columns=['Date', 'OT'])
jets = jets[0:17].drop(columns=['Date', 'OT'])
lions = lions[0:17].drop(columns=['Date', 'OT'])
packers =packers[0:17].drop(columns=['Date', 'OT'])
panthers = panthers[0:17].drop(columns=['Date', 'OT'])
patriots = patriots[0:17].drop(columns=['Date', 'OT'])
raiders = raiders[0:17].drop(columns=['Date', 'OT'])
rams = rams[0:17].drop(columns=['Date', 'OT'])
ravens = ravens[0:17].drop(columns=['Date', 'OT'])
saints = saints[0:17].drop(columns=['Date', 'OT'])
seahawks = seahawks[0:17].drop(columns=['Date', 'OT'])
steelers = steelers[0:17].drop(columns=['Date', 'OT'])
texans = texans[0:17].drop(columns=['Date', 'OT'])
titans = titans[0:17].drop(columns=['Date', 'OT'])
vikings = vikings[0:17].drop(columns=['Date', 'OT'])

broncos.tail()
# Out:
#     Week Result Record Home              Opponent  Points Scored  \
# 12    14      W    7-6    @  Los Angeles Chargers             24
# 13    15      L    7-7    @         Detroit Lions             17
# 14    16      L    7-8  NaN  New England Patriots             23
# 15    17      W    8-8  NaN  Los Angeles Chargers             16
# 16    18      L    8-9    @     Las Vegas Raiders             14
#
#     Points Allowed  1st Downs  Total Yards Gained   Passing Yards  \
# 12               7         19                 322             216
# 13              42         20                 287             204
# 14              26         19                 276             193
# 15               9         16                 313             212
# 16              27         17                 286             238
#
#      Rushing Yards  Turnovers Lost  1st Downs Allowed  Total Yards Allowed  \
# 12             106             1.0                 17                  283
# ...

# %%
niners.insert(0, "Team", 'San Francisco 49ers')
bears.insert(0, "Team", 'Chicago Bears')
bengals.insert(0,"Team",'Cincinnati Bengals')
bills.insert(0, "Team", 'Buffalo Bills')
broncos.insert(0,"Team", 'Denver Broncos')
browns.insert(0, "Team", 'Cleveland Browns')
buccaneers.insert(0, "Team", 'Tampa Bay Buccaneers')
cardinals.insert(0, "Team", 'Arizona Cardinals')
chargers.insert(0, "Team", 'Los Angeles Chargers')
chiefs.insert(0, "Team", 'Kansas City Chiefs')
colts.insert(0, "Team", 'Indianapolis Colts')
commanders.insert(0, "Team", 'Washington Commanders')
cowboys.insert(0, "Team", 'Dallas Cowboys')
dolphins.insert(0, "Team", 'Miami Dolphins')
eagles.insert(0, "Team", 'Philadelphia Eagles')
falcons.insert(0, "Team", 'Atlanta Falcons')
giants.insert(0, "Team", 'New York Giants')
jaguars.insert(0, "Team", 'Jacksonville Jaguars')
jets.insert(0, "Team", 'New York Jets')
lions.insert(0, "Team", 'Detroit Lions')
packers.insert(0, "Team", 'Green Bay Packers')
panthers.insert(0, "Team", 'Carolina Panthers')
patriots.insert(0, "Team", 'New England Patriots')
raiders.insert(0, "Team", 'Las Vegas Raiders')
rams.insert(0, "Team", 'Los Angeles Rams')
ravens.insert(0, "Team", 'Baltimore Ravens')
saints.insert(0, "Team", 'New Orleans Saints')
seahawks.insert(0, "Team", 'Seattle Seahawks')
steelers.insert(0, "Team", 'Pittsburgh Steelers')
texans.insert(0, "Team", 'Houston Texans')
titans.insert(0, "Team", 'Tennessee Titans')
vikings.insert(0, "Team", 'Minnesota Vikings')

broncos.head()
# Out:
#              Team  Week Result Record Home               Opponent  \
# 0  Denver Broncos     1      L    0-1  NaN      Las Vegas Raiders
# 1  Denver Broncos     2      L    0-2  NaN  Washington Commanders
# 2  Denver Broncos     3      L    0-3    @         Miami Dolphins
# 3  Denver Broncos     4      W    1-3    @          Chicago Bears
# 4  Denver Broncos     5      L    1-4  NaN          New York Jets
#
#    Points Scored  Points Allowed  1st Downs  Total Yards Gained  ...  \
# 0             16              17         22                 260  ...
# 1             33              35         21                 399  ...
# 2             20              70         16                 363  ...
# 3             31              28         17                 311  ...
# 4             21              31         18                 308  ...
#
#     Rushing Yards  Turnovers Lost  1st Downs Allowed  Total Yards Allowed  \
# 0              94             NaN                 22                  261
# ...

# %%
nfl_df = pd.concat([niners, 
                   bears,
                   bengals,
                   bills,
                   broncos,
                   browns,
                   buccaneers,
                   cardinals,
                   chargers,
                   chiefs,
                   colts,
                   commanders,
                   cowboys,
                   dolphins,
                   eagles,
                   falcons,
                   giants,
                   jaguars,
                   jets,
                   lions,
                   packers,
                   panthers,
                   patriots,
                   raiders,
                   rams,
                   ravens,
                   saints,
                   seahawks,
                   steelers,
                   texans,
                   titans,
                   vikings
    ]
)

nfl_df
# Out:
#                    Team  Week Result Record Home             Opponent  \
# 0   San Francisco 49ers     1      W    1-0    @  Pittsburgh Steelers
# 1   San Francisco 49ers     2      W    2-0    @     Los Angeles Rams
# 2   San Francisco 49ers     3      W    3-0  NaN      New York Giants
# 3   San Francisco 49ers     4      W    4-0  NaN    Arizona Cardinals
# 4   San Francisco 49ers     5      W    5-0  NaN       Dallas Cowboys
# ..                  ...   ...    ...    ...  ...                  ...
# 12    Minnesota Vikings    14      W    7-6    @    Las Vegas Raiders
# 13    Minnesota Vikings    15      L    7-7    @   Cincinnati Bengals
# 14    Minnesota Vikings    16      L    7-8  NaN        Detroit Lions
# 15    Minnesota Vikings    17      L    7-9  NaN    Green Bay Packers
# 16    Minnesota Vikings    18      L   7-10    @        Detroit Lions
#
#     Points Scored  Points Allowed  1st Downs  Total Yards Gained  ...  \
# ...

# %%
nfl_df = nfl_df.fillna(1)
nfl_df = nfl_df.replace('@', 0)
nfl_df = nfl_df.replace('W', 1)
nfl_df = nfl_df.replace('L', 0)

nfl_df.head()
# Out:
#                   Team  Week  Result Record  Home             Opponent  \
# 0  San Francisco 49ers     1       1    1-0     0  Pittsburgh Steelers
# 1  San Francisco 49ers     2       1    2-0     0     Los Angeles Rams
# 2  San Francisco 49ers     3       1    3-0     1      New York Giants
# 3  San Francisco 49ers     4       1    4-0     1    Arizona Cardinals
# 4  San Francisco 49ers     5       1    5-0     1       Dallas Cowboys
#
#    Points Scored  Points Allowed  1st Downs  Total Yards Gained  ...  \
# 0             30               7         22                 391  ...
# 1             30              23         21                 365  ...
# 2             30              12         26                 441  ...
# 3             35              16         30                 395  ...
# 4             42              10         25                 421  ...
#
#     Rushing Yards  Turnovers Lost  1st Downs Allowed  Total Yards Allowed  \
# ...

# %%
LR = pd.read_csv(('Data/LR_Predictions.csv'), header=0)
ADA = pd.read_csv(('Data/ADA_Predictions.csv'), header=0)
LR.head()
# Out:
#                    Team  Prediction  O_Rank  D_rank  Prediction_Rank
# 0    Kansas City Chiefs    0.441098     1.0    16.0              1.0
# 1   Philadelphia Eagles    0.414003     2.0     8.0              2.0
# 2   San Francisco 49ers    0.407722     6.0     1.0              3.0
# 3  Jacksonville Jaguars    0.401936    10.0    12.0              4.0
# 4  Los Angeles Chargers    0.394781    13.0    21.0              5.0

# %%
LR_prediction = LR[['Team','Prediction']]
ADA_prediction = ADA[['Team', 'Prediction']]

LR_prediction.columns = ['Team','Prediction_LR']
ADA_prediction.columns = ['Team','Prediction_ADA']

# %%
nfl_predictions_df = pd.merge(nfl_df,
                              LR_prediction,
                              left_on='Team', right_on='Team', how='left'
)

final_nfl_predictions_df = pd.merge(nfl_predictions_df,
                              ADA_prediction,
                              left_on='Team', right_on='Team', how='left'
)
final_nfl_predictions_df.head(25)
# Out:
#                    Team  Week  Result Record  Home               Opponent  \
# 0   San Francisco 49ers     1       1    1-0     0    Pittsburgh Steelers
# 1   San Francisco 49ers     2       1    2-0     0       Los Angeles Rams
# 2   San Francisco 49ers     3       1    3-0     1        New York Giants
# 3   San Francisco 49ers     4       1    4-0     1      Arizona Cardinals
# 4   San Francisco 49ers     5       1    5-0     1         Dallas Cowboys
# 5   San Francisco 49ers     6       0    5-1     0       Cleveland Browns
# 6   San Francisco 49ers     7       0    5-2     0      Minnesota Vikings
# 7   San Francisco 49ers     8       0    5-3     1     Cincinnati Bengals
# 8   San Francisco 49ers    10       1    6-3     0   Jacksonville Jaguars
# 9   San Francisco 49ers    11       1    7-3     1   Tampa Bay Buccaneers
# 10  San Francisco 49ers    12       1    8-3     0       Seattle Seahawks
# 11  San Francisco 49ers    13       1    9-3     0    Philadelphia Eagles
# ...

# %%
final_nfl_predictions_df.to_csv('Data/NFL_Predictions_df.csv', index=False)
