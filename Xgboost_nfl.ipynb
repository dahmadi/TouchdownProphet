# %%
import pandas as pd
import numpy as np
import os
import pickle

# %%
pd.set_option('display.max_columns', None)

# %%
path = ("Data/NFL_Predictions_df.csv")
com_data = pd.read_csv(path)
print(com_data.shape)
com_data.head()
# Out:
# (544, 23)
#                   Team  Week  Result Record  Home             Opponent  \
# 0  San Francisco 49ers     1       1    1-0     0  Pittsburgh Steelers
# 1  San Francisco 49ers     2       1    2-0     0     Los Angeles Rams
# 2  San Francisco 49ers     3       1    3-0     1      New York Giants
# 3  San Francisco 49ers     4       1    4-0     1    Arizona Cardinals
# 4  San Francisco 49ers     5       1    5-0     1       Dallas Cowboys
#
#    Points Scored  Points Allowed  1st Downs  Total Yards Gained  \
# 0             30               7         22                 391
# 1             30              23         21                 365
# 2             30              12         26                 441
# 3             35              16         30                 395
# 4             42              10         25                 421
#
#     Passing Yards   Rushing Yards  Turnovers Lost  1st Downs Allowed  \
# 0             203             188             1.0                 15
# 1             206             159             1.0                 28
# 2             300             141             1.0                 10
# 3             271             124             1.0                 23
# 4             251             170             1.0                  8
#
#    Total Yards Allowed  Passing Yards Allowed  Rushing Yards Allowed  \
# 0                  239                    198                     41
# 1                  386                    297                     89
# 2                  150                    121                     29
# 3                  362                    257                    105
# 4                  197                    140                     57
#
#    Turnovers Gained  Offense Expected Points  Defense  Expected Points  \
# 0               2.0                     9.73                     13.55
# 1               2.0                    12.36                     -3.31
# 2               1.0                    19.00                     11.82
# 3               1.0                    30.46                     -9.72
# 4               4.0                    12.84                     23.12
#
#    Special Teams  Expected Points  Prediction_LR  Prediction_ADA
# 0                           -0.78       0.407722        0.033581
# 1                           -2.05       0.407722        0.033581
# 2                           -9.72       0.407722        0.033581
# 3                           -1.63       0.407722        0.033581
# 4                           -5.21       0.407722        0.033581

# %%
# get index of every team's data
team_index = com_data['Team']

# Remove Opponent, Score, Result
xgb_model_data = com_data[['Team','Week','Record','Home','Points Scored','Points Allowed','1st Downs','Total Yards Gained',
                          ' Passing Yards',' Rushing Yards','Turnovers Lost','1st Downs Allowed','Total Yards Allowed',
                          'Passing Yards Allowed','Rushing Yards Allowed','Turnovers Gained','Offense Expected Points',
                          'Defense  Expected Points','Special Teams  Expected Points','Prediction_LR','Prediction_ADA']]


# standardize the data
from sklearn import preprocessing

sd_data = ['1st Downs', 'Total Yards Gained', ' Passing Yards', ' Rushing Yards', 'Turnovers Lost',
                         '1st Downs Allowed', 'Total Yards Allowed', 'Passing Yards Allowed', 'Rushing Yards Allowed', 
                         'Turnovers Gained','Prediction_LR','Prediction_ADA']

xgb_model_data[sd_data] = preprocessing.scale(xgb_model_data[sd_data])

#get indexs of every teams
team_index = com_data['Team']

xgb_model_data = pd.get_dummies(xgb_model_data)
xgb_model_data.head()
# Out:
# C:\Users\james\AppData\Local\Temp\ipykernel_49000\3104970542.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   xgb_model_data[sd_data] = preprocessing.scale(xgb_model_data[sd_data])
#    Week  Home  Points Scored  Points Allowed  1st Downs  Total Yards Gained  \
# 0     1     0             30               7   0.564721            0.691300
# 1     2     0             30              23   0.358541            0.388789
# 2     3     1             30              12   1.389441            1.273051
# 3     4     1             35              16   2.214161            0.737840
# 4     5     1             42              10   1.183261            1.040350
#
#     Passing Yards   Rushing Yards  Turnovers Lost  1st Downs Allowed  \
# 0       -0.212822        1.558456       -0.676373          -0.878539
# 1       -0.172729        0.958573       -0.676373           1.801801
# 2        1.083517        0.586232       -0.676373          -1.909439
# 3        0.695951        0.234576       -0.676373           0.770901
# 4        0.428665        1.186115       -0.676373          -2.321799
#
#    Total Yards Allowed  Passing Yards Allowed  Rushing Yards Allowed  \
# 0            -1.077223              -0.279643              -1.482330
# 1             0.633125               1.043424              -0.489420
# 2            -2.112740              -1.308695              -1.730558
# 3             0.353884               0.508851              -0.158450
# 4            -1.565894              -1.054773              -1.151360
#
#    Turnovers Gained  Offense Expected Points  Defense  Expected Points  \
# 0          0.396359                     9.73                     13.55
# 1          0.396359                    12.36                     -3.31
# 2         -0.676373                    19.00                     11.82
# 3         -0.676373                    30.46                     -9.72
# 4          2.541823                    12.84                     23.12
#
#    Special Teams  Expected Points  Prediction_LR  Prediction_ADA  \
# 0                           -0.78       1.364103        1.728923
# 1                           -2.05       1.364103        1.728923
# 2                           -9.72       1.364103        1.728923
# 3                           -1.63       1.364103        1.728923
# 4                           -5.21       1.364103        1.728923
#
#    Team_Arizona Cardinals  Team_Atlanta Falcons  Team_Baltimore Ravens  \
# 0                   False                 False                  False
# 1                   False                 False                  False
# 2                   False                 False                  False
# 3                   False                 False                  False
# 4                   False                 False                  False
#
#    Team_Buffalo Bills  Team_Carolina Panthers  Team_Chicago Bears  \
# 0               False                   False               False
# 1               False                   False               False
# 2               False                   False               False
# 3               False                   False               False
# 4               False                   False               False
#
#    Team_Cincinnati Bengals  Team_Cleveland Browns  Team_Dallas Cowboys  \
# 0                    False                  False                False
# 1                    False                  False                False
# 2                    False                  False                False
# 3                    False                  False                False
# 4                    False                  False                False
#
#    Team_Denver Broncos  Team_Detroit Lions  Team_Green Bay Packers  \
# 0                False               False                   False
# 1                False               False                   False
# 2                False               False                   False
# 3                False               False                   False
# 4                False               False                   False
#
#    Team_Houston Texans  Team_Indianapolis Colts  Team_Jacksonville Jaguars  \
# 0                False                    False                      False
# 1                False                    False                      False
# 2                False                    False                      False
# 3                False                    False                      False
# 4                False                    False                      False
#
#    Team_Kansas City Chiefs  Team_Las Vegas Raiders  Team_Los Angeles Chargers  \
# 0                    False                   False                      False
# 1                    False                   False                      False
# 2                    False                   False                      False
# 3                    False                   False                      False
# 4                    False                   False                      False
#
#    Team_Los Angeles Rams  Team_Miami Dolphins  Team_Minnesota Vikings  \
# 0                  False                False                   False
# 1                  False                False                   False
# 2                  False                False                   False
# 3                  False                False                   False
# 4                  False                False                   False
#
#    Team_New England Patriots  Team_New Orleans Saints  Team_New York Giants  \
# 0                      False                    False                 False
# 1                      False                    False                 False
# 2                      False                    False                 False
# 3                      False                    False                 False
# 4                      False                    False                 False
#
#    Team_New York Jets  Team_Philadelphia Eagles  Team_Pittsburgh Steelers  \
# 0               False                     False                     False
# 1               False                     False                     False
# 2               False                     False                     False
# 3               False                     False                     False
# 4               False                     False                     False
#
#    Team_San Francisco 49ers  Team_Seattle Seahawks  Team_Tampa Bay Buccaneers  \
# 0                      True                  False                      False
# 1                      True                  False                      False
# 2                      True                  False                      False
# 3                      True                  False                      False
# 4                      True                  False                      False
#
#    Team_Tennessee Titans  Team_Washington Commanders  Record_0-1  Record_0-2  \
# 0                  False                       False       False       False
# 1                  False                       False       False       False
# 2                  False                       False       False       False
# 3                  False                       False       False       False
# 4                  False                       False       False       False
#
#    Record_0-3  Record_0-4  Record_0-5  Record_0-6  Record_1-0  Record_1-1  \
# 0       False       False       False       False        True       False
# 1       False       False       False       False       False       False
# 2       False       False       False       False       False       False
# 3       False       False       False       False       False       False
# 4       False       False       False       False       False       False
#
#    Record_1-10  Record_1-11  Record_1-12  Record_1-2  Record_1-3  Record_1-4  \
# 0        False        False        False       False       False       False
# 1        False        False        False       False       False       False
# 2        False        False        False       False       False       False
# 3        False        False        False       False       False       False
# 4        False        False        False       False       False       False
#
#    Record_1-5  Record_1-6  Record_1-7  Record_1-8  Record_1-9  Record_10-1  \
# 0       False       False       False       False       False        False
# 1       False       False       False       False       False        False
# 2       False       False       False       False       False        False
# 3       False       False       False       False       False        False
# 4       False       False       False       False       False        False
#
#    Record_10-2  Record_10-3  Record_10-4  Record_10-5  Record_10-6  \
# 0        False        False        False        False        False
# 1        False        False        False        False        False
# 2        False        False        False        False        False
# 3        False        False        False        False        False
# 4        False        False        False        False        False
#
#    Record_10-7  Record_11-3  Record_11-4  Record_11-5  Record_11-6  \
# 0        False        False        False        False        False
# 1        False        False        False        False        False
# 2        False        False        False        False        False
# 3        False        False        False        False        False
# 4        False        False        False        False        False
#
#    Record_12-3  Record_12-4  Record_12-5  Record_13-3  Record_13-4  \
# 0        False        False        False        False        False
# 1        False        False        False        False        False
# 2        False        False        False        False        False
# 3        False        False        False        False        False
# 4        False        False        False        False        False
#
#    Record_2-0  Record_2-1  Record_2-10  Record_2-12  Record_2-13  Record_2-14  \
# 0       False       False        False        False        False        False
# 1        True       False        False        False        False        False
# 2       False       False        False        False        False        False
# 3       False       False        False        False        False        False
# 4       False       False        False        False        False        False
#
#    Record_2-15  Record_2-2  Record_2-3  Record_2-4  Record_2-5  Record_2-6  \
# 0        False       False       False       False       False       False
# 1        False       False       False       False       False       False
# 2        False       False       False       False       False       False
# 3        False       False       False       False       False       False
# 4        False       False       False       False       False       False
#
#    Record_2-7  Record_2-8  Record_2-9  Record_3-0  Record_3-1  Record_3-10  \
# 0       False       False       False       False       False        False
# 1       False       False       False       False       False        False
# 2       False       False       False        True       False        False
# 3       False       False       False       False       False        False
# 4       False       False       False       False       False        False
#
#    Record_3-11  Record_3-12  Record_3-2  Record_3-3  Record_3-4  Record_3-5  \
# 0        False        False       False       False       False       False
# 1        False        False       False       False       False       False
# 2        False        False       False       False       False       False
# 3        False        False       False       False       False       False
# 4        False        False       False       False       False       False
#
#    Record_3-6  Record_3-7  Record_3-8  Record_4-0  Record_4-1  Record_4-10  \
# 0       False       False       False       False       False        False
# 1       False       False       False       False       False        False
# 2       False       False       False       False       False        False
# 3       False       False       False        True       False        False
# 4       False       False       False       False       False        False
#
#    Record_4-11  Record_4-12  Record_4-13  Record_4-2  Record_4-3  Record_4-4  \
# 0        False        False        False       False       False       False
# 1        False        False        False       False       False       False
# 2        False        False        False       False       False       False
# 3        False        False        False       False       False       False
# 4        False        False        False       False       False       False
#
#    Record_4-5  Record_4-6  Record_4-7  Record_4-8  Record_4-9  Record_5-0  \
# 0       False       False       False       False       False       False
# 1       False       False       False       False       False       False
# 2       False       False       False       False       False       False
# 3       False       False       False       False       False       False
# 4       False       False       False       False       False        True
#
#    Record_5-1  Record_5-10  Record_5-11  Record_5-12  Record_5-2  Record_5-3  \
# 0       False        False        False        False       False       False
# 1       False        False        False        False       False       False
# 2       False        False        False        False       False       False
# 3       False        False        False        False       False       False
# 4       False        False        False        False       False       False
#
#    Record_5-4  Record_5-5  Record_5-6  Record_5-7  Record_5-8  Record_5-9  \
# 0       False       False       False       False       False       False
# 1       False       False       False       False       False       False
# 2       False       False       False       False       False       False
# 3       False       False       False       False       False       False
# 4       False       False       False       False       False       False
#
#    Record_6-1  Record_6-10  Record_6-11  Record_6-2  Record_6-3  Record_6-4  \
# 0       False        False        False       False       False       False
# 1       False        False        False       False       False       False
# 2       False        False        False       False       False       False
# 3       False        False        False       False       False       False
# 4       False        False        False       False       False       False
#
#    Record_6-5  Record_6-6  Record_6-7  Record_6-8  Record_6-9  Record_7-1  \
# 0       False       False       False       False       False       False
# 1       False       False       False       False       False       False
# 2       False       False       False       False       False       False
# 3       False       False       False       False       False       False
# 4       False       False       False       False       False       False
#
#    Record_7-10  Record_7-2  Record_7-3  Record_7-4  Record_7-5  Record_7-6  \
# 0        False       False       False       False       False       False
# 1        False       False       False       False       False       False
# 2        False       False       False       False       False       False
# 3        False       False       False       False       False       False
# 4        False       False       False       False       False       False
#
#    Record_7-7  Record_7-8  Record_7-9  Record_8-1  Record_8-2  Record_8-3  \
# 0       False       False       False       False       False       False
# 1       False       False       False       False       False       False
# 2       False       False       False       False       False       False
# 3       False       False       False       False       False       False
# 4       False       False       False       False       False       False
#
#    Record_8-4  Record_8-5  Record_8-6  Record_8-7  Record_8-8  Record_8-9  \
# 0       False       False       False       False       False       False
# 1       False       False       False       False       False       False
# 2       False       False       False       False       False       False
# 3       False       False       False       False       False       False
# 4       False       False       False       False       False       False
#
#    Record_9-1  Record_9-3  Record_9-4  Record_9-5  Record_9-6  Record_9-7  \
# 0       False       False       False       False       False       False
# 1       False       False       False       False       False       False
# 2       False       False       False       False       False       False
# 3       False       False       False       False       False       False
# 4       False       False       False       False       False       False
#
#    Record_9-8
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False

# %% [markdown]
# ## Model

# %%
#Gradient Booster Regressor
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from xgboost import plot_tree
from xgboost import XGBRegressor



# Data processing
X = xgb_model_data.drop('Points Scored', axis=1).values
y = xgb_model_data['Points Scored'].values.reshape(-1, 1)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 0.10)

XGB_model = XGBRegressor(random_state=42, objective='reg:squarederror', colsample_bytree=0.7, learning_rate=0.01, max_depth=3, n_estimators=2000 )

XGB_model.fit(X_train, y_train)

y_pred = XGB_model.predict(X_test)

print(mean_absolute_error(y_test, y_pred))
# Out:
# 3.4725932814858176

# %%
best_score = mean_absolute_error(y_test, y_pred)
super_model = XGB_model

super_model
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.7, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.01, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=3, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=2000, n_jobs=None,
#              num_parallel_tree=None, random_state=42, ...)

# %%
Pkl_XGB_model = 'XGBoost_model.sav'
pickle.dump(XGB_model, open(Pkl_XGB_model, 'wb'))

# %%
pd.options.display.max_rows = None

importance = XGB_model.feature_importances_

feature_names = xgb_model_data.drop('Points Scored', axis=1).columns

d = {'Var_Name': feature_names, 'Imp': importance}
df = pd.DataFrame(data=d)
df = df.sort_values(by= ['Imp'], ascending = False).reset_index(drop=True)
df.head(15)

# function that return the score of two teams playing

pd.options.display.max_columns = None

# Create playoff test dataset from season averages

def Score_Predictor(home_team, away_team):
    team1 = home_team
    team2 = away_team
    
    team1_data = xgb_model_data[com_data['Team'] == team1].drop('Points Scored', axis=1).reset_index(drop=True)
    team2_data = xgb_model_data[com_data['Team'] == team2].drop('Points Scored', axis=1).reset_index(drop=True)
    
    week_slice = slice(1,17)
    
    #1 Remove if no team names
    team1_test = pd.DataFrame(team1_data[week_slice].mean(axis=0)).T #select week to use as average
    team1_test
    opp_columns = team1_test.filter(like='Opponent').columns
    
    team1_test[opp_columns] = 0
    team1_test['Team_' + team2] = 1
    team1_test['Home'] = 1
    
    #2
    team2_test = pd.DataFrame(team2_data[week_slice].mean(axis=0)).T #select week to use as average
    opp_columns = team2_test.filter(like='Opponent').columns
    
    team2_test[opp_columns] = 0
    team2_test['Team_' + team1] = 1
    team2_test['Home'] = 0 #remove home field advantage
    
    # head to head matchup
    team1_test[['1st Downs Allowed','Total Yards Allowed','Passing Yards Allowed','Rushing Yards Allowed','Turnovers Gained']] = team2_test[['1st Downs','Total Yards Gained',' Passing Yards',' Rushing Yards','Turnovers Lost']]
    team2_test[['1st Downs Allowed','Total Yards Allowed','Passing Yards Allowed','Rushing Yards Allowed','Turnovers Gained']] = team1_test[['1st Downs','Total Yards Gained',' Passing Yards',' Rushing Yards','Turnovers Lost']]
    
    X_Playoff_test = pd.concat([team1_test, team2_test])
    X_Playoff_test.fillna(0, inplace = True) 
    
    scores = XGB_model.predict(X_Playoff_test)
    print(team1, "will score", round(scores[0], 1))
    print(team2, "will score", round(scores[1], 1))
    
    if scores[0] > scores[1]:
        winner = team1
    else:
        winner = team2
        
    print(winner, "are the WINNERS!!!")
    
    return scores, winner

# %% [markdown]
# ### AFC Wild Card

# %%
scores, winner = Score_Predictor('Cleveland Browns', 'Houston Texans')
# Out:
# Cleveland Browns will score 20.1
# Houston Texans will score 22.4
# Houston Texans are the WINNERS!!!

# %%
scores, winner = Score_Predictor('Miami Dolphins', 'Kansas City Chiefs')
# Out:
# Miami Dolphins will score 26.0
# Kansas City Chiefs will score 21.6
# Miami Dolphins are the WINNERS!!!

# %%
scores, winner = Score_Predictor('Pittsburgh Steelers', 'Buffalo Bills')
# Out:
# Pittsburgh Steelers will score 18.1
# Buffalo Bills will score 24.1
# Buffalo Bills are the WINNERS!!!

# %% [markdown]
# ### NFC Wild Card

# %%
scores, winner = Score_Predictor('Green Bay Packers', 'Dallas Cowboys')
# Out:
# Green Bay Packers will score 23.1
# Dallas Cowboys will score 27.1
# Dallas Cowboys are the WINNERS!!!

# %%
scores, winner = Score_Predictor('Los Angeles Rams', 'Detroit Lions')
# Out:
# Los Angeles Rams will score 21.0
# Detroit Lions will score 26.2
# Detroit Lions are the WINNERS!!!

# %%
scores, winner = Score_Predictor('Philadelphia Eagles', 'Tampa Bay Buccaneers')
# Out:
# Philadelphia Eagles will score 23.8
# Tampa Bay Buccaneers will score 19.4
# Philadelphia Eagles are the WINNERS!!!

# %% [markdown]
# ### AFC Division Round

# %%
scores, winner = Score_Predictor('Houston Texans', 'Baltimore Ravens')
# Out:
# Houston Texans will score 20.3
# Baltimore Ravens will score 28.5
# Baltimore Ravens are the WINNERS!!!

# %%
scores, winner = Score_Predictor('Kansas City Chiefs', 'Buffalo Bills')
# Out:
# Kansas City Chiefs will score 21.7
# Buffalo Bills will score 25.8
# Buffalo Bills are the WINNERS!!!

# %% [markdown]
# ### NFC Division Round

# %%
scores, winner = Score_Predictor('Green Bay Packers', 'San Francisco 49ers')
# Out:
# Green Bay Packers will score 23.2
# San Francisco 49ers will score 27.2
# San Francisco 49ers are the WINNERS!!!

# %%
scores, winner = Score_Predictor('Tampa Bay Buccaneers', 'Detroit Lions')
# Out:
# Tampa Bay Buccaneers will score 19.4
# Detroit Lions will score 25.6
# Detroit Lions are the WINNERS!!!

# %% [markdown]
# ### AFC Championship

# %%
scores, winner = Score_Predictor('Kansas City Chiefs', 'Baltimore Ravens')
# Out:
# Kansas City Chiefs will score 21.8
# Baltimore Ravens will score 28.6
# Baltimore Ravens are the WINNERS!!!

# %% [markdown]
# ### NFC Championship

# %%
scores, winner = Score_Predictor('San Francisco 49ers', 'Detroit Lions')
# Out:
# San Francisco 49ers will score 28.6
# Detroit Lions will score 26.3
# San Francisco 49ers are the WINNERS!!!

# %% [markdown]
# ### Super Bowl

# %%
scores, winner = Score_Predictor('Kansas City Chiefs', 'San Francisco 49ers')
# Out:
# Kansas City Chiefs will score 21.7
# San Francisco 49ers will score 27.9
# San Francisco 49ers are the WINNERS!!!
